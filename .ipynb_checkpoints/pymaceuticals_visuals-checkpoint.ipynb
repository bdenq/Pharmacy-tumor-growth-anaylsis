# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study = pd.merge(study_results, mouse_metadata, how="left")

# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(mouse_study["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
    #inside the dataframe brackets is a boolean series that is used as comparison to the dataframe
mouse_study[mouse_study.duplicated()]
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 137  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_study[mouse_study["Mouse ID"] == "g989"]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_study = mouse_study.drop_duplicates()
clean_mouse_study[clean_mouse_study["Mouse ID"] == "g989"]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_mouse_study["Mouse ID"].unique())
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
drug_stats_mean = clean_mouse_study.groupby(["Drug Regimen"]).mean()
drug_stats_mean_series = drug_stats_mean["Tumor Volume (mm3)"]
drug_stats_median = clean_mouse_study.groupby(["Drug Regimen"]).median()
drug_stats_median_series = drug_stats_median["Tumor Volume (mm3)"]
drug_stats_var = clean_mouse_study.groupby(["Drug Regimen"]).var()
drug_stats_var_series = drug_stats_var["Tumor Volume (mm3)"]
drug_stats_std = clean_mouse_study.groupby(["Drug Regimen"]).std()
drug_stats_std_series = drug_stats_std["Tumor Volume (mm3)"]
drug_stats_sem = clean_mouse_study.groupby(["Drug Regimen"]).sem()
drug_stats_sem_series = drug_stats_sem["Tumor Volume (mm3)"]

# Assemble the resulting series into a single summary DataFrame.
drug_stats_df = pd.DataFrame({
    "Mean Tumor Volume": drug_stats_mean_series,
    "Median Tumor Volume": drug_stats_median_series,
    "Tumor Volume Variance": drug_stats_var_series,
    "Tumor Volume Std. Dev.": drug_stats_std_series,
    "Tumor Volume Std. Err.": drug_stats_sem_series,
})

drug_stats_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.368318            50.909965              42.278090
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
drug_stats_table = clean_mouse_study.groupby("Drug Regimen")
drug_stats_table_agg = drug_stats_table.agg({"Tumor Volume (mm3)" : ['mean', 'median','var', 'std', 'sem']})
drug_stats_table_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
drug_bar_pd_datapoints = clean_mouse_study.groupby("Drug Regimen")["Timepoint"].count().sort_values(ascending=False)

#Creating the bar plot
drug_bar_pd = drug_bar_pd_datapoints.plot.bar(x="Drug Regimen", y="Timepoint")
drug_bar_pd.set_xlabel("Drug Regimen")
drug_bar_pd.set_ylabel("Number of Mice Tested")
# Out:
# Text(0, 0.5, 'Number of Mice Tested')

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

#Creating x-axis by reusing 
drug_bar_plt = clean_mouse_study.groupby("Drug Regimen")["Timepoint"].count().sort_values(ascending=False)
x_axis = drug_bar_plt.index

plt.bar(x_axis, drug_bar_plt)
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.xticks(rotation = 90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_gender_count = clean_mouse_study.groupby("Sex")["Mouse ID"].count()
male_female_pie = mice_gender_count.plot.pie(y = 'Sex', figsize = (4,4),autopct="%1.1f%%")
male_female_pie.set_ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#Creating lists to put into chart
mice_gender_count = clean_mouse_study.groupby("Sex")["Mouse ID"].count()
mice_gender_sum = mice_gender_count.sum()
mice_female_percent = (mice_gender_count["Female"] / mice_gender_sum *100).round()
mice_male_percent = (mice_gender_count["Male"] / mice_gender_sum *100).round()

mice_gender_list_percent = [mice_female_percent,mice_male_percent]
mice_gender_list = mice_gender_count.index.tolist()
colors = ["#FF9933", "#0066CC"]

#Creating pie chart

plt.pie(mice_gender_list_percent, labels=mice_gender_list, colors = colors, autopct="%1.1f%%")
plt.title('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = clean_mouse_study.groupby("Mouse ID")
last_timepoint_max = last_timepoint["Timepoint"].max()
last_timepoint_df = pd.DataFrame(last_timepoint_max)
last_timepoint_df

# #Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
last_timepoint_merge_df = pd.merge(clean_mouse_study, last_timepoint_df, on=['Mouse ID','Timepoint'], how = 'inner')
last_timepoint_merge_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       f932          0           45.000000                 0     Ketapril
# 1       x336          0           45.000000                 0     Naftisol
# 2       h428          0           45.000000                 0     Ketapril
# 3       v199          0           45.000000                 0     Naftisol
# 4       o848          0           45.000000                 0     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 244     r944         45           41.581521                 2    Capomulin
# 245     u364         45           31.023923                 3    Capomulin
# 246     p438         45           61.433892                 1     Ceftamin
# 247     x773         45           58.634971                 4      Placebo
# 248     b879         45           72.555239                 2     Stelasyn
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment = ['Capomulin','Ramicane','Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for i in treatment:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    final_tumor_vol = last_timepoint_merge_df.loc[last_timepoint_merge_df["Drug Regimen"] == i, "Tumor Volume (mm3)"]
    tumor_vol_list.append(final_tumor_vol)
    
    # Setting up the quartiles
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) |(final_tumor_vol > upper_bound)]
    #Showing the outliers 
    print(f"{i}: {outliers}")
# Out:
# Capomulin: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol: 20    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
red_outlier = dict(markerfacecolor='red',markersize=12)
plt.boxplot(tumor_vol_list, labels = treatment, flierprops = red_outlier)
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
cap_data = clean_mouse_study.loc[clean_mouse_study["Drug Regimen"] == "Capomulin"]
mouse_data = cap_data.loc[cap_data["Mouse ID"] == "u364"]

plt.plot(mouse_data["Timepoint"], mouse_data["Tumor Volume (mm3)"])
plt.xlabel("Timepoint in Days")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment of Mouse u364")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
avg_tumor_vol = cap_data.groupby(["Mouse ID"]).mean()
plt.scatter(avg_tumor_vol["Weight (g)"], avg_tumor_vol["Tumor Volume (mm3)"])
plt.xlabel("Weight in Grams")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Average Final Tumor Volume by Weight")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# Add the linear regression equation and line to plot
x_values = avg_tumor_vol["Weight (g)"]
y_values = avg_tumor_vol["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel("Weight in Grams")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Average Final Tumor Volume by Weight")
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
